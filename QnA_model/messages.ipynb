# %%
from langchain_ollama import ChatOllama
from dotenv import load_dotenv
load_dotenv()
model = ChatOllama(model='qwen2.5:3b')
response = model.invoke("Hello")
response.usage_metadata
# Out:
# {'input_tokens': 30, 'output_tokens': 40, 'total_tokens': 70}

# %%
chunks = []
full_message = None
for chunk in model.stream('Hello'):
    chunks.append(chunk)
    print(chunk.text)
    full_message = chunk if full_message is None else full_message+chunk
print(full_message.content)
# Out:
# Hello
# !
#  How
#  can
#  I
#  assist
#  you
#  today
# ?
#
#
# Hello! How can I assist you today?

# %%
from langchain.messages import HumanMessage
model = ChatOllama(model='qwen2.5:3b')
human_mess = HumanMessage(content_blocks=[
    {'type':'text', 'text':'Hello'},
    # {'type':'image_url', 'image_url':{'url':'https://media.istockphoto.com/id/177418652/photo/elephants-touching-each-other-gently.jpg?s=612x612&w=0&k=20&c=O4ttRuDzM3F3Ix3nXOKNP4KClFt3fdsbrJ3Xdp9AQ6g='}}
    {'type':'text', 'text':'what is the name of the model currently in use to answer this question?'}
])
response = model.invoke([human_mess])
response
# Out:
# AIMessage(content='I am Qwen, and I am an artificial intelligence model developed by Alibaba Cloud. My specific architecture and training details may not be publicly disclosed, but I am designed to process and understand natural language inputs like yours and generate appropriate responses. How can I assist you today with your query?', additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-01-19T17:52:12.0505089Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6115973100, 'load_duration': 111942600, 'prompt_eval_count': 46, 'prompt_eval_duration': 106066400, 'eval_count': 58, 'eval_duration': 5821022000, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019bd762-a929-7b51-82ca-ab6a249313dd-0', usage_metadata={'input_tokens': 46, 'output_tokens': 58, 'total_tokens': 104})

# %%
from langchain.messages import AIMessage
message = AIMessage(
    content=[
        {'type':'thinking', 'thinking':'.....', 'signature':'Waaqrfs..'},
        {'type':'text', 'text':'....'}
    ],
    response_metadata={'model_provider':'anthropic'}
)
message.content_blocks
# Out:
# [{'type': 'reasoning',
#   'reasoning': '.....',
#   'extras': {'signature': 'Waaqrfs..'}},
#  {'type': 'text', 'text': '....'}]

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv()
model = ChatGoogleGenerativeAI(model='gemini-3-flash')
human_mess = HumanMessage(content_blocks=[
    {'type':'text', 'text':'Describe the contents of the image.'},
    {'type':'image_url', 'image_url':{'url':'https://media.istockphoto.com/id/177418652/photo/elephants-touching-each-other-gently.jpg?s=612x612&w=0&k=20&c=O4ttRuDzM3F3Ix3nXOKNP4KClFt3fdsbrJ3Xdp9AQ6g='}},
])
response = model.invoke([human_mess])
response
